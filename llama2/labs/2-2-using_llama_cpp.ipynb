# %% [markdown]
# # Querying Llama
#
# Now that we have some knowledge of the fundamentals of how llama 2 is representing data, both within its model
# architecture itself as well as the sequences of tokens coming in and out of the model, we can start to query the model.
# Now, I've used the word "query" here, but I don't mean it in the relational database sense, but in the human language
# sense: to ask a question. A database query is deterministic -- if the data hasn't changed and the query hasn't changed
# then the same result is always returned. But a language model is a bit more nondeterministic, a more precise word to
# describe our interaction with the model is "inference", or "predict".

# %%
# Let's write our first llama.cpp based application.
# To create a new model to query we have to identify the quantized
# file which we want to use. In this course we have two models created
# for experimentation, one being the base 13B paramneter model and the
# other being the chat-tuned 13B parameter model. We'll explore the
# base model first.

# Read in the path for the model file
import os

model_path: str = os.environ["LLAMA_13B"]

# Import the llama.cpp python bindings and load the model
from llama_cpp import Llama

model: Llama = Llama(model_path=model_path)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /data/llama-2-13b.Q5_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 17
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q5_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q5_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 8.60 GiB (5.67 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.18 MiB
# llm_load_tensors:        CPU buffer size =  8801.63 MiB
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 512
# llama_new_context_with_model: n_batch    = 512
# llama_new_context_with_model: n_ubatch   = 512
# llama_new_context_with_model: flash_attn = 0
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_kv_cache_init:        CPU KV buffer size =   400.00 MiB
# llama_new_context_with_model: KV self size  =  400.00 MiB, K (f16):  200.00 MiB, V (f16):  200.00 MiB
# llama_new_context_with_model:        CPU  output buffer size =     0.12 MiB
# llama_new_context_with_model:        CPU compute buffer size =    85.01 MiB
# llama_new_context_with_model: graph nodes  = 1286
# llama_new_context_with_model: graph splits = 1
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 | MATMUL_INT8 = 0 | LLAMAFILE = 1 |
# Model metadata: {'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'general.architecture': 'llama', 'llama.context_length': '4096', 'general.name': 'LLaMA v2', 'llama.embedding_length': '5120', 'llama.feed_forward_length': '13824', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'llama.rope.dimension_count': '128', 'llama.attention.head_count': '40', 'tokenizer.ggml.bos_token_id': '1', 'llama.block_count': '40', 'llama.attention.head_count_kv': '40', 'general.quantization_version': '2', 'tokenizer.ggml.model': 'llama', 'general.file_type': '17'}
# Using fallback chat format: None

# %% [markdown]
# Ok, all we've done is load the model and llama.cpp has given us a ton of debug information! This is worth taking a quick
# look at, especially if you might end up using multiple kinds of models, either different architectures or different
# quantization levels.
#
# We see that this is a llama 2 model, that the context length is up to 4096 tokens - and we'll talk about that in a
# moment - some information about the special tokens which exist for the moment, and if we scroll down we can see the
# number of layers in the model, which speaks to the internal data structure, and whether these have been configured to be
# offloaded onto a GPU or not. One of the interesting options in llama.cpp is that you don't have to choose between the
# CPU or the GPU, you can do a bit of both depending upon your hardware setup.
#
# As we get to the bottom here we see the `llama_new_context_with_model` log lines, and this indicates the default seems
# to be a context of 521 tokens.

# %%
# Before we go further I want to reduce the verbosity of the output
# a bit -- feel free to leave this set to True to see more of the
# nitty gritty details of what's happening!
model.verbose = False

# Now that we have a model let's actually do some inference! The
# method we use for this is called create_completion(), and by
# default we only need to pass it a prompt to complete and it
# returns to us a Completion object, which is a TypedDict.

from llama_cpp.llama_types import *

result: Completion = model.create_completion(prompt="The capital of Michigan is ")

# The Completion type has a choices key which shows us the list of
# responses the LLM generated, let's take a look
print(result["choices"])
# Out:
# [{'text': '53 square miles in size.\nThe Detroit River connects Lake St.', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}]

# %% [markdown]
# Ok! So, if you are following along in the notebook you undoubtedly have a different response than I'm showing here.
# That's what we mean by inference, the model is making a series of probabilistic choices based on the input sequence and
# the weights to generate this output sequence. We can make the model behave more deterministically by setting it's
# `temperature`, which is a parameter from zero to one where values closer to zero cause the model will behave more
# deterministically and values closer to one cause the model to behave more non-deterministic, and creative. Let's do a
# little experiment.

# %%
# Let's try a few different temperature values
temps: list[float] = [0.0, 0.5, 1.0]

# Now, for each of these temperatures, let's do three completions
prompt: str = "The planets in the solar system include "
for temp in temps:
    for i in range(0, 3):
        result: Completion = model.create_completion(prompt=prompt, temperature=temp)
        print(f'temp={temp}, run={i}, result: {result["choices"][0]["text"]}')
# Out:
# temp=0.0, run=0, result: 8 planets, 5 dwarf planets and 123
# temp=0.0, run=1, result: 8 planets, 5 dwarf planets and 123
# temp=0.0, run=2, result: 8 planets, 5 dwarf planets and 123
# temp=0.5, run=0, result: 4 inner planets (Mercury, Venus, Earth and Mars)
# temp=0.5, run=1, result: 8 planets.
# The planets are Mercury, Venus, Earth
# temp=0.5, run=2, result: 8 major planets. The first four are called terrestrial planets and the
# temp=1.0, run=0, result: 8 planets, namely Mercury, Venus, Earth, Mars, Jup
# temp=1.0, run=1, result: 4 rocky terrestrial planets, 2 gas giants, a d
# temp=1.0, run=2, result: 8 planets, Earth is the third planet from sun. The eight planets

# %% [markdown]
# Interesting! We can see that the low temperature returns really consistent results, and that the high remperature gives
# different kinds of answers. Now, don't go reading into the tea leaves too much here, but play with this, experiment and
# get a feeling for how the temperature effects your prompt completions. Underneath the temperature is changing how the
# next token is picked from a set of candidate tokens, so higher levels of temperature will deviate more quickly from one
# another on repeated querying.
#
# You've undoubtedly noticed that we're just getting short little responses here. Generating tokens is slow, and by
# default the `chat_completion()` method limits the number of tokens returned to just 16. We can change this to -1 to
# generate as many tokens as available.

# %%
# Let's just do one run, and we'll leave the temperature at
# it's default value, which is 0.8
result: Completion = model.create_completion(prompt=prompt, max_tokens=-1)
print(result["choices"][0]["text"])
# Out:
# 9, Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune.
# Saturn is the second largest planet of all the planets and is composed mostly of hydrogen and helium gas. It is called a gas giant because it has no solid surface and its density is too low to be considered a proper planet.
# It is surrounded by six rings which are made up of ice, dust, and rock. These rings extend outward for nearly 200,000 km. Saturn's rotation period is 10 hours, 39 minutes. It takes 29.46 Earth years to complete one orbit around the sun.
# Saturn has over 50 moons, of which only 8 are named. Titan, the largest and most dense, is larger than Mercury but has a surface temperature of -178 degrees Celsius. It also has an atmosphere consisting mostly of nitrogen, methane, ethane and other simple hydrocarbons.
# Its rings were first discovered by Galileo in 1610 using his telescope. He noticed that they looked like a crown on the head of Saturn and so named them after Roman gods; Jupiter's moons are named after Greek goddesses, while Uranus's moons are named after Shakespearean characters.
# Saturn has no solid surface due to its low density but it does have an atmosphere consisting mostly of hydrogen and helium gas with small amounts of ammonia and methane. Its temperature is very cold (-300 degrees Celsius) so that it cannot support life as we know it here on Earth today.
# Saturn's diameter at the equator is 120,700 kilometers (75,642 miles) and its mass is 95 times greater than Earth's (making it slightly less dense). It has a thick atmosphere with clouds made up of ammonia ice particles, which are surrounded by a layer of hydrogen sulfide gas.
# The surface temperature on Saturn is about -180 degrees Celsius (-292 Fahrenheit). The planet does not have any solid ground but rather consists entirely of gas and liquid. The atmosphere is mostly made up of nitrogen and helium with small amounts of methane, ammonia, water vapor, carbon dioxide and other gases.
# Saturn's magnetic field is about 60 times stronger than Earth's but it has no solid core like our planet does. It is believed that this difference in strength comes from Saturn being closer to the sun which heats up its atmosphere more than ours does. This causes there to be less carbon dioxide and other gases present in comparison with Earth's atmosphere.
# Saturn has 17 known moons, including Titan, the largest moon in our solar system. It is also the only moon that can support life as we know it here on Earth today due to its thick atmosphere consisting mostly of nitrogen gas and other elements like methane and ammonia.
# Saturn's rings are made up of ice particles and dust grains, which were originally thought to be created by impacts between comets or asteroids. However, recent studies suggest that they may have formed when material from the planet's interior was ejected out into space due to internal heat generated by radioactive elements within it.
# Saturn is unique among the planets because it has a very different structure than any other known body in our solar system. Its density is much lower than that of Earth, and its composition is primarily hydrogen and helium gas. This means that there are no solid surfaces on Saturn; instead, the planet consists entirely of gas and liquid.
# The temperature of Saturn's atmosphere varies depending on how far away from its center you are. The closer to the center you get, the hotter it becomes until finally reaching temperatures around 10 thousand Kelvin (K). This is because as you move farther away from the core, there is less gravitational pull to keep your body in place so that your weight doesn't compress down on top of itself.
# The largest moon of Saturn, Titan, has an atmosphere consisting mostly of nitrogen and methane which are similar to those found here on Earth. However, unlike our planet, it does not have any surface water or land masses as we know them because its surface is covered by ice sheets instead.
# Saturn's rings were first observed by Galileo in 1610 when he used his telescope to study the night sky. He saw what appeared to be two separate circles around the planet, but later discovered that they actually formed one large ring system consisting of seven different bands or rings.
# In 1655 Christiaan Huygens published a book called "Treatise on Light" which described Saturn's rings for the first time in detail. He also proposed that they were made up of particles held together by gravitational force rather than being solid like our planets are today.
# The planet is named after the Roman god Saturnus, who was associated with agriculture and time. The English word "Saturday" comes from this name as well. Saturn's symbol is ♄
# The planet has a diameter of about 120,536 km (74,903 miles) at its equator and weighs in at around 5.68 × 10^26 kg (about 6 times that of Earth). It orbits the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long.
# The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles).
# Saturn's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core. The core itself is believed to be made up primarily of iron with some silicate rock present as well; however this has not been confirmed yet by scientists.
# The planet's atmosphere consists mostly hydrogen gas along with helium, methane, ammonia and other chemicals that are still being studied today. The average pressure at ground level is about 10 millibars or 0.1 bars which is roughly equal to the pressure found here on Earth at sea level (1 bar).
# Saturn has no solid surface due to its low density; however it does have a very thin atmosphere composed mainly of hydrogen gas with traces of helium, methane, ammonia and other elements present as well.
# The planet is also surrounded by a set of rings that are made up mostly of ice particles and dust grains; these were originally thought to be created by impacts between comets or asteroids but recent studies suggest they may have formed when material from the interior was ejected out into space due to internal heat generated by radioactive elements within it.
# Saturn's rings were first observed by Galileo in 1610 using his telescope and he saw what appeared to be two separate circles around the planet, but later discovered they actually formed one large ring system consisting of seven different bands or "rings". In 1655 Christiaan Huygens published a book called Treatise on Light which described Saturn's rings for the first time in detail. He also proposed that they were made up of particles held together by gravitational force rather than being solid like our planets are today; this theory has since been proven correct thanks to advances made over time in technology and science!
# Saturn is the sixth planet from the sun and it's a gas giant. It takes 29 years for Saturn to orbit around its star, which makes it one of the slowest moving planets in our solar system. The planet has a diameter of about 120,536 km (74,903 miles) at its equator and weighs in at around 5.68 × 10^26 kg (about 6 times that of Earth). It orbits the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long.
# The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles). The planet's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core.
# Saturn has no solid surface due to its low density; however it does have a very thin atmosphere composed mainly of hydrogen gas with traces of helium, methane, ammonia and other elements present as well. The average pressure at ground level is about 10 millibars or 0.1 bars which is roughly equal to the pressure found here on Earth at sea level (1 bar). Saturn's atmosphere consists mostly hydrogen gas along with helium, methane, ammonia and other chemicals that are still being studied today.
# Saturn has several unique features that set it apart from other planets in our solar system including its rings which were first observed by Galileo in 1610 using his telescope; he saw what appeared to be two separate circles around the planet, but later discovered they actually formed one large ring system consisting of seven different bands or "rings". In 1655 Christiaan Huygens published a book called Treatise on Light which described Saturn's rings for the first time in detail; he also proposed that they were made up of particles held together by gravitational force rather than being solid like our planets are today; this theory has since been proven correct thanks to advances made over time in technology and science!
# Saturn is unique among all other planets because it does not have any surface water or land masses as we know them due to its surface being covered by ice sheets instead. However, unlike Earth where there are oceans beneath these frozen expanses (such as Antarctica), scientists believe that beneath Saturn's icy shell lies another layer composed mostly of gas and liquid which could contain more complex lifeforms than those found here on Earth today!
# The planet is named after the Roman god Saturnus, who was associated with agriculture and time. The English word "Saturday" comes from this name as well. Saturn's symbol is ♄ . It orbits around the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long. The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles). The planet's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core.
# The planet has a diameter of about 120,536 km (74,903 miles) at its equator and weighs in at around 5.68 × 10^26 kg (about 6 times that of Earth). It orbits the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long.
# The planet has no solid surface due to its low density; however it does have a very thin atmosphere composed mainly of hydrogen gas with traces of helium, methane, ammonia and other elements present as well. The average pressure at ground level is about 10 millibars or 0.1 bars which is roughly equal to the pressure found here on Earth at sea level (1 bar). Saturn's atmosphere consists mostly hydrogen gas along with helium, methane, ammonia and other chemicals that are still being studied today.
# The planet is unique among all other planets because it does not have any surface water or land masses as we know them due to its surface being covered by ice sheets instead. However, unlike Earth where there are oceans beneath these frozen expanses (such as Antarctica), scientists believe that beneath Saturn's icy shell lies another layer composed mostly of gas and liquid which could contain more complex lifeforms than those found here on Earth today! The planet is named after the Roman god Saturnus, who was associated with agriculture and time. The English word "Saturday" comes from this name as well. Saturn's symbol is ♄ . It orbits around the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long. The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles). The planet's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core.
# Saturn is the sixth planet from the sun and it's a gas giant. It takes 29 years for Saturn to orbit around its star, which makes it one of the slowest moving planets in our solar system. The planet has a diameter of about 120,536 km (74,903 miles) at its equator and weighs in at around 5.68 × 10^26 kg (about 6 times that of Earth). It orbits the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long. The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles). The planet's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core.
# Saturn has no solid surface due to its low density; however it does have a very thin atmosphere composed mainly of hydrogen gas with traces of helium, methane, ammonia and other elements present as well. The average pressure at ground level is about 10 millibars or 0.1 bars which is roughly equal to the pressure found here on Earth at sea level (1 bar). Saturn's atmosphere consists mostly hydrogen gas along with helium, methane, ammonia and other chemicals that are still being studied today. The planet has a diameter of about 120,536 km (74,903 miles) at its equator and weighs in at around 5.68 × 10^26 kg (about 6 times that of Earth). It orbits the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long. The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less than half that of Earth. It also has a radius of 7.3 x 10^4 km, or 7.3 billion kilometers (about 4 billion miles). The planet's surface temperature ranges from -271 to -180 degrees Celsius (-456 to -302 Fahrenheit) depending on where you are looking at it and how close you are getting to its core.
# The planet is named after the Roman god Saturnus, who was associated with agriculture and time. The English word "Saturday" comes from this name as well. Saturn's symbol is ♄ . It orbits around the sun every 29 years with an average distance from it being about 1.4 billion km (900 million miles). Its day length is approximately 10 hours 39 minutes and its year length is about 29.5 earth days long. The planet has a mass of 5.68 x 10^26 kg, or 5.68 trillion metric tons. This is more than twice the mass of Jupiter, but less

# %% [markdown]
# Ok, the first thing you'll notice, especially if you are following along in the lab workspaces with me, is that it's
# slow. We're already running this model in a quantized form, so to speed things up further we need to either get better
# hardware, or further reduce the model size, perhaps through additional quantization. You'll also likely notice -- and I
# say likely because everything here is non-deterministic -- that the model still doesn't just "finish". It trails off
# eventually, but not at 16 characters. And this comes down to the content length.

# %% [markdown]
# # Context Length
#
# Once you understand tokenization the context length is really simple, it's just the maximum length of the token sequence
# that the model is trained on. In the case of the original llama model the context length was just over two thousand
# tokens (2,024), which means the input data used for training the model was broken up into a maximum this length of
# sequence. For llama 2 that was increased to over four thousand tokens (4,096).
#
# You can think of the context length like the amount of "memory" that an LLM has for a given query. The bigger it is the
# more you can put in the query and thus the more the LLM will be aware of when return to you a response. Training -- and
# inference -- with a large context length can increase quality of the output, but they do so at the cost of increased
# computation. When you create a new `Llama()` object in llama.cpp the default maximum context length is set to 512
# tokens.

# %%
# Let's do one last demo, and here I want to show you how we don't have to
# wait for whole query to finish, but can instead use the streaming features
# of llama.cpp to see tokens as they are completed.

# I'm going to create a new model with a nice large context size
model: Llama = Llama(model_path=model_path, verbose=False, n_ctx=4096)

# If we pass the stream=True parameter to create_completion() we will get back
# an iterator of CreatCompletionStreamResponse objects, which are just typed
# dictionaries similar to the Completion type
token_count: int = 0
for result in model.create_completion(
    prompt="Some fun things to do for vacation in the state of Michigan includes ",
    max_tokens=-1,
    stream=True,
):
    # I'm only going to print a newline every 50 tokens or so
    if token_count % 50 == 0:
        print("")
    token_count = token_count + 1
    print(result["choices"][0]["text"], end="")
# Out:
# 4-wheeling, camping, fishing and golf.
# Michigan has a large number of campgrounds. People who enjoy roughing it will find many places to camp and hike. In fact, some of the parks
#  have hiking trails that allow you to get away from civilization for a couple of hours or even overnight.
# The most popular state park is Sleeping Bear Dunes National Lakeshore. This park has 35
#  miles of shoreline and miles of sand dunes that people can walk along. There are also nature trails where people can view some of the wildlife in the area. People who enjoy hiking will find over 100 miles
#  of trails at the Sleeping Bear Dunes National Lakeshore.
# Pictured Rocks National Lakeshore is a park along Lake Superior that has sandstone cliffs, beaches and waterfalls. There are
#  also nature trails that allow people to see some of the wildlife in the area.
# Other state parks include:
# Potawatomi State Park: This park has 80 miles of ATV and motorcycle trails as
#  well as horseback riding.
# Indian Lake State Park: This campground is close to the city of Indian River and is popular with fishermen. In fact, the state record for northern pike was caught in this lake.
#
# Tahquamenon Falls State Park: This park has a beautiful 49 foot waterfall that attracts visitors from all over Michigan. There are many other things to do at the park including hiking and fishing.
# Gr
# and Haven State Park: This park is located on Lake Michigan and has sandy beaches, dunes and forests. It also has a lighthouse that can be toured.
# Norway Beach State Park: This campground
#  is located on Lake Superior and is popular with people who enjoy fishing and boating. There are miles of hiking trails in the area as well.
# People who want to enjoy the outdoors in Michigan have many places
#  to choose from. Campers will find many state parks that offer a variety of activities including hiking, biking and fishing. People who like ATV's or motorcycles will also find plenty of places to ride them
#  around in the state of Michigan.
# Pictured Rocks National Lakeshore is one of the most popular things to do for vacation in Michigan. This park has sandstone cliffs, beaches and waterfalls. There are also
#  nature trails that allow people to see some of the wildlife in the area. The Pictured Rocks National Lakeshore was created to protect the natural beauty of this area on Lake Superior's shore.
# Michigan is
#  a state with many things to do for vacation. One thing that you can do is go camping and fishing. Another thing that you can do is explore some of Michigan's beautiful parks, such as Sleeping Bear Dunes
#  National Lakeshore or Pictured Rocks National Lakeshore. You could also try your hand at 4-wheeling or golfing while visiting this state.
# There are many things to do for vacation in
#  Michigan. Here are a few ideas:
# Visit the Detroit Zoo: The zoo is one of the most popular attractions in Michigan and offers something for everyone. From gorillas to penguins, there's something for all ages
#  at the Detroit Zoo!
# Explore Mackinac Island: This beautiful island is just a ferry ride away from mainland Michigan and has plenty of things to do including hiking trails, bicycle rentals, horse
# -drawn carriage rides, shopping and more. Plus, you can't miss out on some fudge while you're there!
# Visit Sleeping Bear Dunes National Lakeshore: This national park is
#  located along the shores of Lake Michigan in northern lower peninsula Michigan. It features over 30 miles of sandy beaches as well as towering dunes that make for some great hiking trails and scenic views.
#
# Hike Mount Mitchell or Pictured Rocks National Lakeshore: Both are located within easy driving distance from each other but offer different experiences depending on what you're looking for. For example, if you want to get away from
